# %% [markdown]
# ### Data Jumlah kejadian bencana banjir 10 Provinsi tahun 2021

# %%
print('''Data ini berisi tentang Jumlah kejadian bencana banjir di indonesia tahun 2021 
memfokuskan 10 provinsi yang ada di Indonesia''')

print("Sumber data: " )
print("https://www.bps.go.id/id/statistics-table/3/TUZaMGVteFVjSEJ4T1RCMlIyRjRTazVvVDJocVFUMDkjMw==/jumlah-bencana-alam-menurut-provinsi-dan-jenis-bencana-alam--kejadian---2021.html?year=2021")
# Out:
# Data ini berisi tentang Jumlah kejadian bencana banjir di indonesia tahun 2021
# memfokuskan 10 provinsi yang ada di Indonesia
# Sumber data:
# https://www.bps.go.id/id/statistics-table/3/TUZaMGVteFVjSEJ4T1RCMlIyRjRTazVvVDJocVFUMDkjMw==/jumlah-bencana-alam-menurut-provinsi-dan-jenis-bencana-alam--kejadian---2021.html?year=2021

# %%
import pandas as pd #mengimport module pandas untuk manipulasi data
import openpyxl as op # menimport module openpyxl untuk membaca file exel

data =pd.read_excel(r"C:\Users\Michael Zidane\Downloads\matana project\Jumlah Kejadian Bencana Alam Menurut Provinsi 2021 new version.xlsx") # mengimport file excel ke jupyternotebook
df = pd.DataFrame(data) #membuat data frame

df.iloc[:, 0:5] #menampilkan preview data
# Out:
#                      Provinsi   Tanah Longsor   Banjir  \
# 0                        Aceh            11.0    100.0
# 1              Sumatera Utara            23.0     83.0
# 2              Sumatera Barat            18.0     58.0
# 3                        Riau             7.0     67.0
# 4                       Jambi            11.0     37.0
# 5            Sumatera Selatan             4.0     39.0
# 6                    Bengkulu             9.0     25.0
# 7                     Lampung             5.0     25.0
# 8   Kepulauan Bangka Belitung             2.0     15.0
# 9              Kepulauan Riau             5.0     14.0
# 10                DKI Jakarta            14.0     20.0
# 11                 Jawa Barat           613.0    247.0
# 12                Jawa Tengah           238.0    153.0
# 13              DI Yogyakarta            17.0      6.0
# 14                 Jawa Timur            76.0    149.0
# 15                     Banten            14.0     57.0
# 16                       Bali            63.0     13.0
# 17        Nusa Tenggara Barat            10.0     79.0
# 18        Nusa Tenggara Timur            24.0     59.0
# 19           Kalimantan Barat             4.0     45.0
# 20          Kalimantan Tengah             0.0      0.0
# 21         Kalimantan Selatan            12.0     62.0
# 22           Kalimantan Timur            46.0     36.0
# 23           Kalimantan Utara            32.0     16.0
# 24             Sulawesi Utara             3.0     23.0
# 25            Sulawesi Tengah             4.0     96.0
# 26           Sulawesi Selatan            24.0     68.0
# 27          Sulawesi Tenggara             8.0     38.0
# 28                  Gorontalo             7.0     22.0
# 29             Sulawesi Barat             4.0     23.0
# 30                     Maluku            14.0     23.0
# 31               Maluku Utara             2.0     20.0
# 32                Papua Barat             1.0      5.0
# 33                      Papua             1.0     20.0
# 34                        NaN             NaN      NaN
#
#      Kebakaran Hutan dan Lahan  Cuaca Ekstrem
# 0                         77.0           91.0
# 1                         13.0           54.0
# 2                         16.0          118.0
# 3                         44.0           24.0
# 4                         24.0           24.0
# 5                         24.0           24.0
# 6                          0.0           11.0
# 7                          0.0           46.0
# 8                         10.0           13.0
# 9                         79.0            6.0
# 10                         0.0           16.0
# 11                        14.0          478.0
# 12                        13.0          206.0
# 13                         0.0            2.0
# 14                         8.0          122.0
# 15                         3.0           39.0
# 16                         1.0            8.0
# 17                         0.0           17.0
# 18                         1.0           28.0
# 19                        10.0            9.0
# 20                         0.0            0.0
# 21                       165.0           32.0
# 22                        29.0            7.0
# 23                         8.0            3.0
# 24                         1.0           13.0
# 25                         0.0           36.0
# 26                         0.0           90.0
# 27                         0.0           21.0
# 28                         0.0           10.0
# 29                         0.0            9.0
# 30                         0.0           19.0
# 31                         0.0           10.0
# 32                         1.0            1.0
# 33                         0.0            3.0
# 34                         NaN            NaN

# %%
df_top10 = df.sort_values(by="Banjir", ascending=False).head(10)

plt.figure(figsize=(8,8))

plt.pie(
    df_top10["Banjir"],
    labels=df_top10["Provinsi"],
    autopct="%1.1f%%"
)

plt.title("10 Provinsi dengan Banjir Terbanyak")
plt.axis("equal")
plt.show()

# %%
import matplotlib.pyplot as plt

df_10 = df.head(10)

plt.figure(figsize=(10,6))

plt.bar(df_10["Provinsi"], df_10["Banjir"])

plt.title("Jumlah Kejadian Banjir")
plt.xlabel("Provinsi")
plt.ylabel("Jumlah Banjir")

plt.xticks(rotation=45)  # supaya nama provinsi miring biar kebaca
plt.show()
